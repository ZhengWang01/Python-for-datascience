# %% [markdown]
# # Twitter data
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# # Twitter API Access
#
# Twitter implements OAuth 1.0A as its standard authentication mechanism, and in order to use it to make requests to Twitter's API, you'll need to go to https://dev.twitter.com/apps and create a sample application.
#
# Choose any name for your application, write a description and use `http://google.com` for the website.
#
# Under **Key and Access Tokens**, there are four primary identifiers you'll need to note for an OAuth 1.0A workflow:
# * consumer key,
# * consumer secret,
# * access token, and
# * access token secret (Click on Create Access Token to create those).
#
# Note that you will need an ordinary Twitter account in order to login, create an app, and get these credentials.

# %% [markdown]
# The first time you execute the notebook, add all credentials so that you can save them in the `pkl` file, then you can remove the secret keys from the notebook because they will just be loaded from the `pkl` file.
#
# The `pkl` file contains sensitive information that can be used to take control of your twitter acccount, **do not share it**.

# %%
import pickle
import os

# %%
if not os.path.exists('secret_twitter_credentials.pkl'):
    Twitter={}
    Twitter['Consumer Key'] = ''
    Twitter['Consumer Secret'] = ''
    Twitter['Access Token'] = ''
    Twitter['Access Token Secret'] = ''
    with open('secret_twitter_credentials.pkl','wb') as f:
        pickle.dump(Twitter, f)
else:
    Twitter=pickle.load(open('secret_twitter_credentials.pkl','rb'))

# %% [markdown]
# Install the `twitter` package to interface with the Twitter API

# %%
# !pip install twitter
# Out:
# Collecting twitter
#   Downloading https://files.pythonhosted.org/packages/85/e2/f602e3f584503f03e0389491b251464f8ecfe2596ac86e6b9068fe7419d3/twitter-1.18.0-py2.py3-none-any.whl (54kB)
#      |████████████████████████████████| 61kB 1.2MB/s eta 0:00:01
# Installing collected packages: twitter
# Successfully installed twitter-1.18.0

# %% [markdown]
# ## Example 1. Authorizing an application to access Twitter account data

# %%
import twitter

auth = twitter.oauth.OAuth(Twitter['Access Token'],
                           Twitter['Access Token Secret'],
                           Twitter['Consumer Key'],
                           Twitter['Consumer Secret'])

twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x10a65d950>

# %% [markdown]
# ## Example 2. Retrieving trends

# %% [markdown]
# Twitter identifies locations using the Yahoo! Where On Earth ID.
#
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/
#
# look at the BOSS placefinder here: https://developer.yahoo.com/boss/placefinder/

# %%
WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# %% [markdown]
# Look for the WOEID for [san-diego](http://woeid.rosselliot.co.nz/lookup/san%20diego%20%20ca)
#
# You can change it to another location.

# %%
LOCAL_WOE_ID=2487889

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)
local_trends = twitter_api.trends.place(_id=LOCAL_WOE_ID)

# %%
world_trends[:2]

# %%
trends=local_trends
print(type(trends))
print(list(trends[0].keys()))
print(trends[0]['trends'])
# Out:
# <class 'twitter.api.TwitterListResponse'>
# ['trends', 'as_of', 'created_at', 'locations']
# [{'name': '#CoronavirusPandemic', 'url': 'http://twitter.com/search?q=%23CoronavirusPandemic', 'promoted_content': None, 'query': '%23CoronavirusPandemic', 'tweet_volume': 351466}, {'name': 'Tom Hanks', 'url': 'http://twitter.com/search?q=%22Tom+Hanks%22', 'promoted_content': None, 'query': '%22Tom+Hanks%22', 'tweet_volume': 1106700}, {'name': 'COVID-19', 'url': 'http://twitter.com/search?q=COVID-19', 'promoted_content': None, 'query': 'COVID-19', 'tweet_volume': 3470080}, {'name': 'Europe', 'url': 'http://twitter.com/search?q=Europe', 'promoted_content': None, 'query': 'Europe', 'tweet_volume': 1000718}, {'name': 'Rudy Gobert', 'url': 'http://twitter.com/search?q=%22Rudy+Gobert%22', 'promoted_content': None, 'query': '%22Rudy+Gobert%22', 'tweet_volume': 815881}, {'name': 'March Madness', 'url': 'http://twitter.com/search?q=%22March+Madness%22', 'promoted_content': None, 'query': '%22March+Madness%22', 'tweet_volume': 198814}, {'name': 'Donovan Mitchell', 'url': 'http://twitter.com/search?q=%22Donovan+Mitchell%22', 'promoted_content': None, 'query': '%22Donovan+Mitchell%22', 'tweet_volume': 178098}, {'name': 'Big East', 'url': 'http://twitter.com/search?q=%22Big+East%22', 'promoted_content': None, 'query': '%22Big+East%22', 'tweet_volume': 16721}, {'name': '#SUGASPREE', 'url': 'http://twitter.com/search?q=%23SUGASPREE', 'promoted_content': None, 'query': '%23SUGASPREE', 'tweet_volume': None}, {'name': '#TrumptheWorstPresidentEVER', 'url': 'http://twitter.com/search?q=%23TrumptheWorstPresidentEVER', 'promoted_content': None, 'query': '%23TrumptheWorstPresidentEVER', 'tweet_volume': 27906}, {'name': 'Tom Cotton', 'url': 'http://twitter.com/search?q=%22Tom+Cotton%22', 'promoted_content': None, 'query': '%22Tom+Cotton%22', 'tweet_volume': None}, {'name': '#CancelEverythingNow', 'url': 'http://twitter.com/search?q=%23CancelEverythingNow', 'promoted_content': None, 'query': '%23CancelEverythingNow', 'tweet_volume': 13466}, {'name': '#ThursdayMotivation', 'url': 'http://twitter.com/search?q=%23ThursdayMotivation', 'promoted_content': None, 'query': '%23ThursdayMotivation', 'tweet_volume': 37105}, {'name': '77% of Americans', 'url': 'http://twitter.com/search?q=%2277%25+of+Americans%22', 'promoted_content': None, 'query': '%2277%25+of+Americans%22', 'tweet_volume': 19757}, {'name': 'Fast 9', 'url': 'http://twitter.com/search?q=%22Fast+9%22', 'promoted_content': None, 'query': '%22Fast+9%22', 'tweet_volume': None}, {'name': 'Spida', 'url': 'http://twitter.com/search?q=Spida', 'promoted_content': None, 'query': 'Spida', 'tweet_volume': None}, {'name': 'Doe Boy', 'url': 'http://twitter.com/search?q=%22Doe+Boy%22', 'promoted_content': None, 'query': '%22Doe+Boy%22', 'tweet_volume': None}, {'name': 'Major League Soccer', 'url': 'http://twitter.com/search?q=%22Major+League+Soccer%22', 'promoted_content': None, 'query': '%22Major+League+Soccer%22', 'tweet_volume': None}, {'name': 'Tomorrow is Friday the 13th', 'url': 'http://twitter.com/search?q=%22Tomorrow+is+Friday+the+13th%22', 'promoted_content': None, 'query': '%22Tomorrow+is+Friday+the+13th%22', 'tweet_volume': None}, {'name': "St. John's and Creighton", 'url': 'http://twitter.com/search?q=%22St.+John%27s+and+Creighton%22', 'promoted_content': None, 'query': '%22St.+John%27s+and+Creighton%22', 'tweet_volume': None}, {'name': 'The ACC', 'url': 'http://twitter.com/search?q=%22The+ACC%22', 'promoted_content': None, 'query': '%22The+ACC%22', 'tweet_volume': 12964}, {'name': 'Veto', 'url': 'http://twitter.com/search?q=Veto', 'promoted_content': None, 'query': 'Veto', 'tweet_volume': 160543}, {'name': 'Guardia Nacional', 'url': 'http://twitter.com/search?q=%22Guardia+Nacional%22', 'promoted_content': None, 'query': '%22Guardia+Nacional%22', 'tweet_volume': None}, {'name': 'Tornado Watch', 'url': 'http://twitter.com/search?q=%22Tornado+Watch%22', 'promoted_content': None, 'query': '%22Tornado+Watch%22', 'tweet_volume': None}, {'name': 'Katie Porter', 'url': 'http://twitter.com/search?q=%22Kat ...

# %% [markdown]
# ## Example 3. Displaying API responses as pretty-printed JSON

# %%
import json

print((json.dumps(us_trends[:2], indent=1)))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "#CoronavirusPandemic",
#     "url": "http://twitter.com/search?q=%23CoronavirusPandemic",
#     "promoted_content": null,
#     "query": "%23CoronavirusPandemic",
#     "tweet_volume": 351466
#    },
#    {
#     "name": "Donovan Mitchell",
#     "url": "http://twitter.com/search?q=%22Donovan+Mitchell%22",
#     "promoted_content": null,
#     "query": "%22Donovan+Mitchell%22",
#     "tweet_volume": 178098
#    },
#    {
#     "name": "Big East",
#     "url": "http://twitter.com/search?q=%22Big+East%22",
#     "promoted_content": null,
#     "query": "%22Big+East%22",
#     "tweet_volume": 16721
#    },
#    {
#     "name": "#SUGASPREE",
#     "url": "http://twitter.com/search?q=%23SUGASPREE",
#     "promoted_content": null,
#     "query": "%23SUGASPREE",
#     "tweet_volume": null
#    },
#    {
#     "name": "#TrumptheWorstPresidentEVER",
#     "url": "http://twitter.com/search?q=%23TrumptheWorstPresidentEVER",
#     "promoted_content": null,
#     "query": "%23TrumptheWorstPresidentEVER",
#     "tweet_volume": 27906
#    },
#    {
#     "name": "Rudy",
#     "url": "http://twitter.com/search?q=Rudy",
#     "promoted_content": null,
#     "query": "Rudy",
#     "tweet_volume": 920487
#    },
#    {
#     "name": "Gobert",
#     "url": "http://twitter.com/search?q=Gobert",
#     "promoted_content": null,
#     "query": "Gobert",
#     "tweet_volume": 918399
#    },
#    {
#     "name": "Tom Cotton",
#     "url": "http://twitter.com/search?q=%22Tom+Cotton%22",
#     "promoted_content": null,
#     "query": "%22Tom+Cotton%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "#CancelEverythingNow",
#     "url": "http://twitter.com/search?q=%23CancelEverythingNow",
#     "promoted_content": null,
#     "query": "%23CancelEverythingNow",
#     "tweet_volume": 13466
#    },
#    {
#     "name": "#ThursdayMotivation",
#     "url": "http://twitter.com/search?q=%23ThursdayMotivation",
#     "promoted_content": null,
#     "query": "%23ThursdayMotivation",
#     "tweet_volume": 37105
#    },
#    {
#     "name": "77% of Americans",
#     "url": "http://twitter.com/search?q=%2277%25+of+Americans%22",
#     "promoted_content": null,
#     "query": "%2277%25+of+Americans%22",
#     "tweet_volume": 19757
#    },
#    {
#     "name": "May Madness",
#     "url": "http://twitter.com/search?q=%22May+Madness%22",
#     "promoted_content": null,
#     "query": "%22May+Madness%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Fast 9",
#     "url": "http://twitter.com/search?q=%22Fast+9%22",
#     "promoted_content": null,
#     "query": "%22Fast+9%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Spida",
#     "url": "http://twitter.com/search?q=Spida",
#     "promoted_content": null,
#     "query": "Spida",
#     "tweet_volume": null
#    },
#    {
#     "name": "Doe Boy",
#     "url": "http://twitter.com/search?q=%22Doe+Boy%22",
#     "promoted_content": null,
#     "query": "%22Doe+Boy%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Major League Soccer",
#     "url": "http://twitter.com/search?q=%22Major+League+Soccer%22",
#     "promoted_content": null,
#     "query": "%22Major+League+Soccer%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Tomorrow is Friday the 13th",
#     "url": "http://twitter.com/search?q=%22Tomorrow+is+Friday+the+13th%22",
#     "promoted_content": null,
#     "query": "%22Tomorrow+is+Friday+the+13th%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "St. John's and Creighton",
#     "url": "http://twitter.com/search?q=%22St.+John%27s+and+Creighton%22",
#     "promoted_content": null,
#     "query": "%22St.+John%27s+and+Creighton%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "The ACC",
#     "url": "http://twitter.com/search?q=%22The+ACC%22",
#     "promoted_content": null,
#     "query": "%22The+ACC%22",
#     "tweet_volume": 12964
#    },
#    {
#     "name": "Veto",
#     "url": "http://twitter.com/search?q=Veto",
#     "promoted_content": null,
#     "query": "Veto",
#     "tweet_volume": 160543
#    },
#    {
#     "name": "Guardia Nacional",
#     "url": "http://twitter.com/search?q=%22Guardia+Nacional%22",
#     "promoted_content": null,
#     "query": "%22Guardia+Nacional%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Tornado Watch",
#     "url": "http://twitter.com/search?q=%22Tornado+Watch%22",
#     "promoted_content": null,
#     "query": "%22Tornado+Watch%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Katie Porter",
#     "url": "http://twitter.com/search?q=%22Katie+Porter%22",
#     "promoted_content": null,
#     "query": "%22Katie+Porter%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Chet Hanks",
#     "url": "http://twitter.com/search?q=%22Chet+Hanks%22",
#     "promoted_content": null,
#     "query": "%22Chet+Hanks%22",
#     "tweet_volume": 15267
#    },
#    {
#     "name": "Brian Epstein",
#     "url": "http://twitter.com/search?q=%22Brian+Epstein%22",
#     "promoted_content": null,
#     "query": "%22Brian+Epstein%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Dion Lewis",
#     "url": "http://twitter.com/search?q=%22Dion+Lewis%22",
#     "promoted_content": null,
#     "query": "%22Dion+Lewis%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "John Swofford",
#     "url": "http://twitter.com/search?q=%22John+Swofford%22",
#     "promoted_content": null,
#     "query": "%22John+Swofford%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "the big ten tournament",
#     "url": "http://twitter.com/search?q=%22the+big+ten+tournament%22",
#     "promoted_content": null,
#     "query": "%22the+big+ten+tournament%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Princess Cruises",
#     "url": "http://twitter.com/search?q=%22Princess+Cruises%22",
#     "promoted_content": null,
#     "query": "%22Princess+Cruises%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Fabio Wajngarten",
#     "url": "http://twitter.com/search?q=%22Fabio+Wajngarten%22",
#     "promoted_content": null,
#     "query": "%22Fabio+Wajngarten%22",
#     "tweet_volume": 27716
#    },
#    {
#     "name": "Recess",
#     "url": "http://twitter.com/search?q=Recess",
#     "promoted_content": null,
#     "query": "Recess",
#     "tweet_volume": 29070
#    },
#    {
#     "name": "valero texas open",
#     "url": "http://twitter.com/search?q=%22valero+texas+open%22",
#     "promoted_content": null,
#     "query": "%22valero+texas+open%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "ACC Champions",
#     "url": "http://twitter.com/search?q=%22ACC+Champions%22",
#     "promoted_content": null,
#     "query": "%22ACC+Champions%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Jack Kerouac",
#     "url": "http://twitter.com/search?q=%22Jack+Kerouac%22",
#     "promoted_content": null,
#     "query": "%22Jack+Kerouac%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Planet of the Apes",
#     "url": "http://twitter.com/search?q=%22Planet+of+the+Apes%22",
#     "promoted_content": null,
#     "query": "%22Planet+of+the+Apes%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Conference USA",
#     "url": "http://twitter.com/search?q=%22Conference+USA%22",
#     "promoted_content": null,
#     "query": "%22Conference+USA%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "#WhereAreTheTests",
#     "url": "http://twitter.com/search?q=%23WhereAreTheTests",
#     "promoted_content": null,
#     "query": "%23WhereAreTheTests",
#     "tweet_volume": null
#    },
#    {
#     "name": "#OurEnergyBeomgyuDay",
#     "url": "http://twitter.com/search?q=%23OurEnergyBeomgyuDay",
#     "promoted_content": null,
#     "query": "%23OurEnergyBeomgyuDay",
#     "tweet_volume": 359170
#    },
#    {
#     "name": "#LOONA1stWin",
#     "url": "http://twitter.com/search?q=%23LOONA1stWin",
#     "promoted_content": null,
#     "query": "%23LOONA1stWin",
#     "tweet_volume": 292310
#    },
#    {
#     "name": "#AskMandyMoore",
#     "url": "http://twitter.com/search?q=%23AskMandyMoore",
#     "promoted_content": null,
#     "query": "%23AskMandyMoore",
#     "tweet_volume": null
#    },
#    {
#     "name": "#AQuietPlace2",
#     "url": "http://twitter.com/search?q=%23AQuietPlace2",
#     "promoted_content": null,
#     "query": "%23AQuietPlace2",
#     "tweet_volume": null
#    },
#    {
#     "name": "#SandersSisters",
#     "url": "http://twitter.com/search?q=%23SandersSisters",
#     "promoted_content": null,
#     "query": "%23SandersSisters",
#     "tweet_volume": null
#    },
#    {
#     "name": "#IMakeItWeirdBy",
#     "url": "http://twitter.com/search?q=%23IMakeItWeirdBy",
#     "promoted_content": null,
#     "query": "%23IMakeItWeirdBy",
#     "tweet_volume": null
#    },
#    {
#     "name": "#FamiliesFirst",
#     "url": "http://twitter.com/search?q=%23FamiliesFirst",
#     "promoted_content": null,
#     "query": "%23FamiliesFirst",
#     "tweet_volume": 30310
#    },
#    {
#     "name": "#sweetnightapproaching",
#     "url": "http://twitter.com/search?q=%23sweetnightapproaching",
#     "promoted_content": null,
#     "query": "%23sweetnightapproaching",
#     "tweet_volume": 51628
#    },
#    {
#     "name": "#ACCTournament",
#     "url": "http://twitter.com/search?q=%23ACCTournament",
#     "promoted_content": null,
#     "query": "%23ACCTournament",
#     "tweet_volume": null
#    },
#    {
#     "name": "#MonbebeSelcaDay",
#     "url": "http://twitter.com/search?q=%23MonbebeSelcaDay",
#     "promoted_content": null,
#     "query": "%23MonbebeSelcaDay",
#     "tweet_volume": 18359
#    },
#    {
#     "name": "#askCDC",
#     "url": "http://twitter.com/search?q=%23askCDC",
#     "promoted_content": null,
#     "query": "%23askCDC",
#     "tweet_volume": null
#    },
#    {
#     "name": "#PixarSoul",
#     "url": "http://twitter.com/search?q=%23PixarSoul",
#     "promoted_content": null,
#     "query": "%23PixarSoul",
#     "tweet_volume": 11610
#    },
#    {
#     "name": "#WhatTheIrishDoBetter",
#     "url": "http://twitter.com/search?q=%23WhatTheIrishDoBetter",
#     "promoted_content": null,
#     "query": "%23WhatTheIrishDoBetter",
#     "tweet_volume": null
#    }
#   ],
#   "as_of": "2020-03-12T17:15:41Z",
#   "created_at": "2020-03-12T17:10:06Z",
#   "locations": [
#    {
#     "name": "United States",
#     "woeid": 23424977
#    }
#   ]
#  }
# ]

# %% [markdown]
# ## Example 4. Computing the intersection of two sets of trends

# %%
trends_set = {}
trends_set['world'] = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

trends_set['us'] = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 

trends_set['san diego'] = set([trend['name'] 
                     for trend in local_trends[0]['trends']])

# %%
for loc in ['world','us','san diego']:
    print(('-'*10,loc))
    print((','.join(trends_set[loc])))
# Out:
# ('----------', 'world')
# #SüresizSözleşmeliyeKadro,#CoğrafyacılarÜveyEvlatDeğil,Metro Manila,Big East,#หุ่นหมีของพ่อจ๋า,#عيسي_بن_راشد,#CobraMeeting,#Dia15VaiSerGigante,JUNTOS COM PRIOR E BABU,#CoronavirusEnArgentina,Tom Cotton,でぶビンゴ,#MersindeBüyükDolandırıcı,#아무데나_감자를_붙이면_하찮아진다,#バンドリアニメ3rd_07,#Covid_19,#LOONA1stWin,#関西弁,#中島健人誕生祭,#우리의_따뜻한_봄_명수야_생일축하해,#YoMeQuedoEnCasa,#امر_اخلاء,#MonbebeSelcaDay,Donovan Mitchell,#Belediye5393eKadro,#MaçlarErtelensin,#LQvKK,#NehaDhupia,#خافو_الله_وش_هالقلوب,#cekirgeistilası,#FelizJueves,미스터트롯,Üniversiteler 3,#SweetNightApproaching,#ForaBabu,#sevgilimbenikarisiylaaldatti,#millieğitimbakanlığı,#DanceMentorLALISA,#evdetekbaşına,#okullartatil,#12Mar,#LaRadioDelHincha,Nisan,#TrumptheWorstPresidentEVER,#SUGASPREE,#Priorexpulso,Duterte,#halukleventsözleşmelimağdur,#OurEnergyBeomgyuDay,#MücahidÖren
# ('----------', 'us')
# Tomorrow is Friday the 13th,valero texas open,Guardia Nacional,#PixarSoul,#FamiliesFirst,Big East,Chet Hanks,#sweetnightapproaching,#ThursdayMotivation,Major League Soccer,St. John's and Creighton,Jack Kerouac,#AQuietPlace2,#AskMandyMoore,Tom Cotton,#CoronavirusPandemic,Rudy,Katie Porter,#IMakeItWeirdBy,#WhereAreTheTests,Princess Cruises,#LOONA1stWin,Tornado Watch,Gobert,Brian Epstein,Planet of the Apes,ACC Champions,#askCDC,#MonbebeSelcaDay,Donovan Mitchell,Conference USA,Recess,Fabio Wajngarten,the big ten tournament,The ACC,John Swofford,Fast 9,Spida,#ACCTournament,May Madness,#SandersSisters,#WhatTheIrishDoBetter,#TrumptheWorstPresidentEVER,#SUGASPREE,77% of Americans,Dion Lewis,#OurEnergyBeomgyuDay,Veto,Doe Boy,#CancelEverythingNow
# ('----------', 'san diego')
# Tomorrow is Friday the 13th,valero texas open,Guardia Nacional,#PixarSoul,#FamiliesFirst,Big East,Rudy Gobert,#sweetnightapproaching,#ThursdayMotivation,Major League Soccer,Tom Hanks,St. John's and Creighton,Jack Kerouac,#AQuietPlace2,#AskMandyMoore,Tom Cotton,#CoronavirusPandemic,#IMakeItWeirdBy,Katie Porter,#WhereAreTheTests,Princess Cruises,#LOONA1stWin,COVID-19,Tornado Watch,Brian Epstein,Planet of the Apes,ACC Champions,#askCDC,#MonbebeSelcaDay,Donovan Mitchell,Europe,Recess,Fabio Wajngarten,the big ten tournament,The ACC,John Swofford,Fast 9,Spida,#ACCTournament,March Madness,#SandersSisters,#WhatTheIrishDoBetter,#TrumptheWorstPresidentEVER,#SUGASPREE,77% of Americans,Dion Lewis,#OurEnergyBeomgyuDay,Veto,Doe Boy,#CancelEverythingNow

# %%
print(( '='*10,'intersection of world and us'))
print((trends_set['world'].intersection(trends_set['us'])))

print(('='*10,'intersection of us and san-diego'))
print((trends_set['san diego'].intersection(trends_set['us'])))
# Out:
# ('==========', 'intersection of world and us')
# {'#MonbebeSelcaDay', 'Donovan Mitchell', 'Tom Cotton', '#TrumptheWorstPresidentEVER', '#LOONA1stWin', '#SUGASPREE', 'Big East', '#OurEnergyBeomgyuDay'}
# ('==========', 'intersection of us and san-diego')
# {'Tomorrow is Friday the 13th', 'valero texas open', 'Guardia Nacional', '#PixarSoul', '#FamiliesFirst', 'Big East', '#sweetnightapproaching', '#ThursdayMotivation', 'Major League Soccer', "St. John's and Creighton", 'Jack Kerouac', '#AQuietPlace2', '#AskMandyMoore', 'Tom Cotton', '#CoronavirusPandemic', '#IMakeItWeirdBy', 'Katie Porter', '#WhereAreTheTests', 'Princess Cruises', '#LOONA1stWin', 'Tornado Watch', 'Brian Epstein', 'Planet of the Apes', 'ACC Champions', '#askCDC', '#MonbebeSelcaDay', 'Donovan Mitchell', 'Recess', 'Fabio Wajngarten', 'the big ten tournament', 'The ACC', 'John Swofford', 'Fast 9', 'Spida', '#ACCTournament', '#SandersSisters', '#WhatTheIrishDoBetter', '#TrumptheWorstPresidentEVER', '#SUGASPREE', '77% of Americans', 'Dion Lewis', '#OurEnergyBeomgyuDay', 'Veto', 'Doe Boy', '#CancelEverythingNow'}

# %% [markdown]
# ## Example 5. Collecting search results

# %% [markdown]
# Set the variable `q` to a trending topic,
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter

# %%
q = '#TrumptheWorstPresidentEVER' 

number = 100

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=number)

statuses = search_results['statuses']

# %%
len(statuses)
print(statuses)
# Out:
# [{'created_at': 'Thu Mar 12 17:32:07 +0000 2020', 'id': 1238155828194152448, 'id_str': '1238155828194152448', 'text': 'RT @Pappiness: When the market drops 7%, it triggers a circuit breaker and stops trading for 15 minutes.\n\nThe first and only time it happen…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'Pappiness', 'name': 'Nick Jack Pappas', 'id': 30726383, 'id_str': '30726383', 'indices': [3, 13]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 17172863, 'id_str': '17172863', 'name': 'Jasper Lucas', 'screen_name': 'JGRIDLOCK', 'location': 'United States', 'description': 'Progressive who loves sports & politics; despise Trumpsters. #SheWonThePopularVote #TrumpIsACriminal #ImpeachTrumpNow #Resistance #FBR', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 3017, 'friends_count': 4987, 'listed_count': 53, 'created_at': 'Tue Nov 04 23:32:01 +0000 2008', 'favourites_count': 99102, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 125945, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1115172205455974400/gjtAZrLw_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1115172205455974400/gjtAZrLw_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Thu Mar 12 13:45:21 +0000 2020', 'id': 1238098758740643841, 'id_str': '1238098758740643841', 'text': 'When the market drops 7%, it triggers a circuit breaker and stops trading for 15 minutes.\n\nThe first and only time… https://t.co/OUbU96p4wH', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/OUbU96p4wH', 'expanded_url': 'https://twitter.com/i/web/status/1238098758740643841', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [116, 139]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 30726383, 'id_str': '30726383', 'name': 'Nick Jack Pappas', 'screen_name': 'Pappiness', 'location': 'New York, NY', 'description': "Writer | Comedian | Director | Filipino-American 🇵🇭🇺🇸. @NBC Late Night Writers' Workshop. @ucbtny writer.", 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 93620, 'friends_count': 3617, 'listed_count': 899, 'created_at': 'Sun Apr 12 21:34:15 +0000 2009', 'favourites_count': 23343, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 5885, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '0C0F0B', 'profile_ ...

# %% [markdown]
# Twitter often returns duplicate results, we can filter them out checking for duplicate texts:

# %%
all_text = []
filtered_statuses = []
for s in statuses:
    if not s["text"] in all_text:
        filtered_statuses.append(s)
        all_text.append(s["text"])
statuses = filtered_statuses

# %%
len(statuses)
# Out:
# 60

# %%
[s['text'] for s in search_results['statuses']]
# Out:
# ['RT @Pappiness: When the market drops 7%, it triggers a circuit breaker and stops trading for 15 minutes.\n\nThe first and only time it happen…',
#  "RT @raggapegs: '@realdonaldtrump ranked worst president in US history by nearly 200 political scientists.' I'm shocked!😱 #TrumptheWorstPres…",
#  'RT @AppSame: #TrumptheWorstPresidentEVER\n\nBlaming Trump for the #CoronavirusPandemic \n\nProves how evil @TheDemocrats are',
#  'RT @Pappiness: When the market drops 7%, it triggers a circuit breaker and stops trading for 15 minutes.\n\nThe first and only time it happen…',
#  "RT @jackresists: This has been the most bungled response to a crisis I've seen in my lifetime.\n\n#TrumptheWorstPresidentEVER",
#  'Alright, bust out the replacement-bot!\n#TrumptheWorstPresidentEVER \n\n"President Model #16"\n[The Spoils - Unlikely H… https://t.co/qOz9Hko6sj',
#  'RT @415holgate: Can we have the Presidential Election TOMORROW? Enough already. #TrumptheWorstPresidentEVER #TrumpNotFitForOffice #PenceUnf…',
#  'RT @AynRandPaulRyan: Two weeks.\nTrump said "anyone who wants a test can get one."\nThat was last Friday.\nUtter bullshit.\n\n#coronaviruspandem…',
#  "Fed announces massive stimulus package for BANKS to save stock markets. Meanwhile, consumers like you and me can't… https://t.co/61H8n6zB9m",
#  '@AngrierWHStaff More importantly, are they ready to admit —\n#TrumptheWorstPresidentEVER… https://t.co/v7Bcf88XAT',
#  'RT @Pappiness: When the market drops 7%, it triggers a circuit breaker and stops trading for 15 minutes.\n\nThe first and only time it happen…',
#  'RT @JoanTurri: Would now be a good time to remind everyone that over 170 economists approve Bernie Sanders economic plan? 🤔\n#CoronavirusPan…',
#  'RT @mjfree: Nancy Pelosi should be made acting President of the United States effective immediately. \n\n#CoronavirusPandemic #TrumptheWorstP…',
#  "@pastorlocke What's the difference? \n#hoax #CorruptDNC #corruptnewsmedia #TDS \n#TrumptheWorstPresidentEVER \n\n#qanon… https://t.co/dqriDJreNj",
#  '#TrumptheWorstPresidentEVER Another crappy hashtag title created by another warp minded individual.',
#  '@BrandonBeckham_ @realDonaldTrump @kilmeade @foxandfriends Brandon Beckham Esq. Is it true you paint your banana or… https://t.co/BPHfPiVF0S',
#  'RT @mjfree: Nancy Pelosi should be made acting President of the United States effective immediately. \n\n#CoronavirusPandemic #TrumptheWorstP…',
#  'RT @AK52979491: #CoronavirusPandemic #Trumpspeech #TrumptheWorstPresidentEVER  \nHas court failed to give Harvey Weinstein a fair trial unde…',
#  'RT @middleageriot: I miss having a president who would be willing to skip a game of golf to keep us from dying.\n\n#TrumptheWorstPresidentEVER',
#  'RT @NY_runaway: #Covid_19 and the #TrumpVirus are just two reasons to defeat tRump in 2020.  He has no true concern for your healthy wellbe…',
#  'RT @415holgate: Can we have the Presidential Election TOMORROW? Enough already. #TrumptheWorstPresidentEVER #TrumpNotFitForOffice #PenceUnf…',
#  'RT @AynRandPaulRyan: Savannah Guthrie handing Mike Pence his ass on a platter is a whooooooleass mood.\n\n#CoronavirusPandemic #trumpspeech #…',
#  'RT @AynRandPaulRyan: Savannah Guthrie handing Mike Pence his ass on a platter is a whooooooleass mood.\n\n#CoronavirusPandemic #trumpspeech #…',
#  'RT @cwebbonline: Is it a coincidence the stock market crashes every time Trump opens his mouth about #coronavirus? \n#TrumpAddress\n#Trumpthe…',
#  "I'm glad #TrumptheWorstPresidentEVER is trending. Keep that energy in November",
#  'RT @mjfree: Nancy Pelosi should be made acting President of the United States effective immediately. \n\n#CoronavirusPandemic #TrumptheWorstP…',
#  '#TrumptheWorstPresidentEVER we know he is, now give ryujin views  https://t.co/zVBiuqV8FC',
#  'RT @jacquelyn_rene: Just sayin. #TrumptheWorstPresidentEVER https://t.co/pNqTMQX1i2',
#  'RT @AynRandPaulRyan: Savannah Guthrie handing Mike Pence his ass on a platter is a whooooooleass mood.\n\n#CoronavirusPandemic #trumpspeech #…',
#  'RT @yokoboji: 🎉🎉THURSDAY Party🎉🎉\n\nFollow Back Resistance Party.\n\nFollow all who:\n\nLIKE ❤️ \nRETWEET 🔁\nCOMMENT 💬\n\nDrop your favorite meme or…',
#  'RT @AynRandPaulRyan: Two weeks.\nTrump said "anyone who wants a test can get one."\nThat was last Friday.\nUtter bullshit.\n\n#coronaviruspandem…',
#  'RT @AynRandPaulRyan: Two weeks.\nTrump said "anyone who wants a test can get one."\nThat was last Friday.\nUtter bullshit.\n\n#coronaviruspandem…',
#  "A Narcissistic Idiot That's Going To Destroy The Country &amp; Get us All Killed!!😡🤮🤮\n\n#TrumptheWorstPresidentEVER… https://t.co/0WfdJS1XVY",
#  '😂🤣😅 #TrumpTrain2020 \n\n #TrumptheWorstPresidentEVER https://t.co/aY3sBhSahZ',
#  '#TrumpVirus #TrumptheWorstPresidentEVER #TrumpVirusTestingFailure #TrumpVirus2020 https://t.co/rA3lo3Zu3G',
#  'RT @mcspocky: #TrumptheWorstPresidentEVER\nTwo things make Donald Trump unfit for office: https://t.co/xGsgDvIlT6',
#  "RT @raggapegs: The Dow is now down 1,600 at 9:50 AM EDT.  Can't make this sh*t up! #Pandumbic #CPACvirus    #ImpeachedForLife  #TrumptheWor…",
#  'RT @Pappiness: When the market drops 7%, it triggers a circuit breaker and stops trading for 15 minutes.\n\nThe first and only time it happen…',
#  'RT @ColonelAngus7: Liberals are literally rooting for a virus to kill people, tank the economy and destroy the stock market. All because of…',
#  'RT @AynRandPaulRyan: Savannah Guthrie handing Mike Pence his ass on a platter is a whooooooleass mood.\n\n#CoronavirusPandemic #trumpspeech #…',
#  'So what happens when postal workers get sick? This virus has shelf life different materials not to mention it’s air… https://t.co/nK6HWXpTLQ',
#  'RT @LetsTrySanity: @TheRavenFay1 @AdamCC75 Right. So the numbers in the US will stay nice and low...🙄🙄🙄\nPOtuS is a moron...\n##TrumptheWorst…',
#  'RT @jacquelyn_rene: Just sayin. #TrumptheWorstPresidentEVER https://t.co/pNqTMQX1i2',
#  "RT @middleageriot: If only there'd been some indication that Donald Trump lacked the intellectual and emotional capacity to handle a nation…",
#  '@nowthisnews He is a disgrace and not fit to get us thru this crisis. #TrumptheWorstPresidentEVER',
#  'RT @TheValuesVoter: I’ll be sick if the stock market crash is the thing that finally costs Trump support w/Evangelicals.\n\nTaking kids from…',
#  'RT @NY_runaway: #Covid_19 and the #TrumpVirus are just two reasons to defeat tRump in 2020.  He has no true concern for your healthy wellbe…',
#  "RT @tun2real: Problem is his supporters still listen to the Rt Wing Media spin so they don't see his miserable fail on this.#TrumptheWorstP…",
#  'RT @sjredmond: Did China refuse WHO tests for the US.\nDid China tell Americans the virus was a hoax?\nDid China cut funding to the CDC?\nDid…',
#  'Can’t think of a another one in the history of humanity #TrumptheWorstPresidentEVER',
#  'RT @yokoboji: 🎉🎉THURSDAY Party🎉🎉\n\nFollow Back Resistance Party.\n\nFollow all who:\n\nLIKE ❤️ \nRETWEET 🔁\nCOMMENT 💬\n\nDrop your favorite meme or…',
#  'RT @sjredmond: Did China refuse WHO tests for the US.\nDid China tell Americans the virus was a hoax?\nDid China cut funding to the CDC?\nDid…',
#  '#TrumptheWorstPresidentEVER. #BestPresidentEver https://t.co/kcTIalWnfL',
#  "RT @middleageriot: If only there'd been some indication that Donald Trump lacked the intellectual and emotional capacity to handle a nation…",
#  "RT @jackresists: This has been the most bungled response to a crisis I've seen in my lifetime.\n\n#TrumptheWorstPresidentEVER",
#  'Republicans: We don’t agree w/science and facts, and we will keep saying no to things that need to be done to stop… https://t.co/vdAtoOqm7U',
#  'RT @AynRandPaulRyan: Savannah Guthrie handing Mike Pence his ass on a platter is a whooooooleass mood.\n\n#CoronavirusPandemic #trumpspeech #…',
#  'RT @TheValuesVoter: I’ll be sick if the stock market crash is the thing that finally costs Trump support w/Evangelicals.\n\nTaking kids from…',
#  '#Coronavirus funding held up by #GOP because of ‘abortion’ — and people are furious: ‘Saving fetuses over actual li… https://t.co/JhzbOy0fEw',
#  '"free testing" ..... and the Turtle breath asshats are holding out until after recess!!!!!!!… https://t.co/fITqOdbHvF',
#  'It’s always constantly about the money, I’m getting tired of this #TrumptheWorstPresidentEVER #trumpsucks https://t.co/tHXhlRzbPL',
#  "RT @middleageriot: If only there'd been some indication that Donald Trump lacked the intellectual and emotional capacity to handle a nation…",
#  'RT @AynRandPaulRyan: Savannah Guthrie handing Mike Pence his ass on a platter is a whooooooleass mood.\n\n#CoronavirusPandemic #trumpspeech #…',
#  "RT @JRehling: Trump's nine-minute speech to calm the nation contained four important errors of fact that had to be corrected immediately.…",
#  'RT @maydaymindy9: Trump will go down in History as the Worst President Ever, Melanie as the laziest and most selfish First Lady and Trumps…',
#  'RT @mcspocky: #TrumptheWorstPresidentEVER\nTwo things make Donald Trump unfit for office: https://t.co/xGsgDvIlT6',
#  'RT @AynRandPaulRyan: Savannah Guthrie handing Mike Pence his ass on a platter is a whooooooleass mood.\n\n#CoronavirusPandemic #trumpspeech #…',
#  'RT @hobbitseeker: So @JoeBiden is putting together a task force for Coronavirus with actual public health experts and scientists and is any…',
#  'RT @maydaymindy9: Trump will go down in History as the Worst President Ever, Melanie as the laziest and most selfish First Lady and Trumps…',
#  'RT @AynRandPaulRyan: Two weeks.\nTrump said "anyone who wants a test can get one."\nThat was last Friday.\nUtter bullshit.\n\n#coronaviruspandem…',
#  "RT @middleageriot: If only there'd been some indication that Donald Trump lacked the intellectual and emotional capacity to handle a nation…",
#  'RT @mcspocky: #TrumptheWorstPresidentEVER\nTwo things make Donald Trump unfit for office: https://t.co/xGsgDvIlT6',
#  "RT @middleageriot: If only there'd been some indication that Donald Trump lacked the intellectual and emotional capacity to handle a nation…",
#  'RT @YvetteMorel_: Because everyone knows #TrumptheWorstPresidentEVER !!! https://t.co/v76lE0gJQE',
#  'RT @mjfree: Nancy Pelosi should be made acting President of the United States effective immediately. \n\n#CoronavirusPandemic #TrumptheWorstP…',
#  'RT @Pappiness: When the market drops 7%, it triggers a circuit breaker and stops trading for 15 minutes.\n\nThe first and only time it happen…',
#  "RT @middleageriot: If only there'd been some indication that Donald Trump lacked the intellectual and emotional capacity to handle a nation…",
#  'RT @NoNoNotNormal: Chump BLOCKED the U.S. from getting tests.\n\n#WhereAreTheTests \n\n#TrumptheWorstPresidentEVER\n\nhttps://t.co/nibBjedvKD',
#  '#CoronavirusPandemic #trumpspeech #trumptheworstpresidentever #COVD19',
#  'RT @nhdogmom: #TrumptheWorstPresidentEVER\n\nTrump’s CDC has only tested 77 people for coronavirus this week | Raw Story https://t.co/fy4qRvY…',
#  'RT @johnpavlovitz: Pandemics thrive on fear and fear is your only commodity. \n\nIn the raking light of an actual emergency, you are being re…',
#  'Dm with the state of your needs, we rise by lifting others. #Teampulte #CoronavirusPandemic #CoronaVirusUpdate… https://t.co/0mWDDymumh',
#  '#TrumptheWorstPresidentEVER #CoronavirusPandemic #COVD19 #Covid_19 https://t.co/NVdpX1eYy4',
#  'RT @Pappiness: When the market drops 7%, it triggers a circuit breaker and stops trading for 15 minutes.\n\nThe first and only time it happen…',
#  'RT @TheValuesVoter: I’ll be sick if the stock market crash is the thing that finally costs Trump support w/Evangelicals.\n\nTaking kids from…',
#  'RT @yokoboji: 🎉🎉THURSDAY Party🎉🎉\n\nFollow Back Resistance Party.\n\nFollow all who:\n\nLIKE ❤️ \nRETWEET 🔁\nCOMMENT 💬\n\nDrop your favorite meme or…',
#  "RT @middleageriot: If only there'd been some indication that Donald Trump lacked the intellectual and emotional capacity to handle a nation…",
#  'RT @maydaymindy9: Trump will go down in History as the Worst President Ever, Melanie as the laziest and most selfish First Lady and Trumps…',
#  "RT @jackresists: This has been the most bungled response to a crisis I've seen in my lifetime.\n\n#TrumptheWorstPresidentEVER",
#  'RT @cwebbonline: Is it a coincidence the stock market crashes every time Trump opens his mouth about #coronavirus? \n#TrumpAddress\n#Trumpthe…',
#  '@senatemajldr and do nothing @GOP #DoNothingGOP #GOPBetrayedAmerica #TrumptheWorstPresidentEVER https://t.co/FpvkrpdPqI',
#  'You spelled Obama wrong  #TrumptheWorstPresidentEVER',
#  '#CoronavirusPandemic #Trumpspeech #TrumptheWorstPresidentEVER  \nHas court failed to give Harvey Weinstein a fair tr… https://t.co/DKnYJIYjiv',
#  'RT @AynRandPaulRyan: Yeah, he sounds really worried.\nWhat an ass.\n#TrumptheWorstPresidentEVER',
#  'RT @AynRandPaulRyan: Savannah Guthrie handing Mike Pence his ass on a platter is a whooooooleass mood.\n\n#CoronavirusPandemic #trumpspeech #…',
#  '@NoNoNotNormal Gosh! I hate all this winning!\n#TrumptheWorstPresidentEVER',
#  'RT @mcspocky: #TrumptheWorstPresidentEVER\nTwo things make Donald Trump unfit for office: https://t.co/xGsgDvIlT6',
#  'Every time that Donald Trump opens his mouth the stock market nosedives.\n\nIt’s time that investors sue the Trump ad… https://t.co/N1MiWIrHod',
#  'RT @k74111: @businessinsider "Paid sick leave, free testing, and a solution for uninsured Americans were all missing,"  he added.\n\nOh, you…',
#  '@realDonaldTrump You are a freaking moron.  While you may not be concerned about your exposure to the COVID-19 (cou… https://t.co/4IK534lnQi']

# %%
# Show one sample search result by slicing the list...
print(json.dumps(statuses[0], indent=1))
# Out:
# {
#  "created_at": "Thu Mar 12 17:32:07 +0000 2020",
#  "id": 1238155828194152448,
#  "id_str": "1238155828194152448",
#  "text": "RT @Pappiness: When the market drops 7%, it triggers a circuit breaker and stops trading for 15 minutes.\n\nThe first and only time it happen\u2026",
#  "truncated": false,
#  "entities": {
#   "hashtags": [],
#   "symbols": [],
#   "user_mentions": [
#    {
#     "screen_name": "Pappiness",
#     "name": "Nick Jack Pappas",
#     "id": 30726383,
#     "id_str": "30726383",
#     "indices": [
#      3,
#      13
#     ]
#    }
#   ],
#   "urls": []
#  },
#  "metadata": {
#   "iso_language_code": "en",
#   "result_type": "recent"
#  },
#  "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#  "in_reply_to_status_id": null,
#  "in_reply_to_status_id_str": null,
#  "in_reply_to_user_id": null,
#  "in_reply_to_user_id_str": null,
#  "in_reply_to_screen_name": null,
#  "user": {
#   "id": 17172863,
#   "id_str": "17172863",
#   "name": "Jasper Lucas",
#   "screen_name": "JGRIDLOCK",
#   "location": "United States",
#   "description": "Progressive who loves sports & politics; despise Trumpsters. #SheWonThePopularVote #TrumpIsACriminal #ImpeachTrumpNow #Resistance #FBR",
#   "url": null,
#   "entities": {
#    "description": {
#     "urls": []
#    }
#   },
#   "protected": false,
#   "followers_count": 3017,
#   "friends_count": 4987,
#   "listed_count": 53,
#   "created_at": "Tue Nov 04 23:32:01 +0000 2008",
#   "favourites_count": 99102,
#   "utc_offset": null,
#   "time_zone": null,
#   "geo_enabled": false,
#   "verified": false,
#   "statuses_count": 125945,
#   "lang": null,
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "C0DEED",
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#   "profile_background_tile": false,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/1115172205455974400/gjtAZrLw_normal.jpg",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/1115172205455974400/gjtAZrLw_normal.jpg",
#   "profile_link_color": "1DA1F2",
#   "profile_sidebar_border_color": "C0DEED",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "profile_text_color": "333333",
#   "profile_use_background_image": true,
#   "has_extended_profile": true,
#   "default_profile": true,
#   "default_profile_image": false,
#   "following": false,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "none"
#  },
#  "geo": null,
#  "coordinates": null,
#  "place": null,
#  "contributors": null,
#  "retweeted_status": {
#   "created_at": "Thu Mar 12 13:45:21 +0000 2020",
#   "id": 1238098758740643841,
#   "id_str": "1238098758740643841",
#   "text": "When the market drops 7%, it triggers a circuit breaker and stops trading for 15 minutes.\n\nThe first and only time\u2026 https://t.co/OUbU96p4wH",
#   "truncated": true,
#   "entities": {
#    "hashtags": [],
#    "symbols": [],
#    "user_mentions": [],
#    "urls": [
#     {
#      "url": "https://t.co/OUbU96p4wH",
#      "expanded_url": "https://twitter.com/i/web/status/1238098758740643841",
#      "display_url": "twitter.com/i/web/status/1\u2026",
#      "indices": [
#       116,
#       139
#      ]
#     }
#    ]
#   },
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 30726383,
#    "id_str": "30726383",
#    "name": "Nick Jack Pappas",
#    "screen_name": "Pappiness",
#    "location": "New York, NY",
#    "description": "Writer | Comedian | Director | Filipino-American \ud83c\uddf5\ud83c\udded\ud83c\uddfa\ud83c\uddf8. @NBC Late Night Writers' Workshop. @ucbtny writer.",
#    "url": null,
#    "entities": {
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
#    "followers_count": 93620,
#    "friends_count": 3617,
#    "listed_count": 899,
#    "created_at": "Sun Apr 12 21:34:15 +0000 2009",
#    "favourites_count": 23343,
#    "utc_offset": null,
#    "time_zone": null,
#    "geo_enabled": true,
#    "verified": true,
#    "statuses_count": 5885,
#    "lang": null,
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "0C0F0B",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme12/bg.gif",
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme12/bg.gif",
#    "profile_background_tile": false,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/1236007219860250624/D-ASNIOf_normal.jpg",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/1236007219860250624/D-ASNIOf_normal.jpg",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/30726383/1578447939",
#    "profile_link_color": "337DCC",
#    "profile_sidebar_border_color": "F2E195",
#    "profile_sidebar_fill_color": "FFF7CC",
#    "profile_text_color": "0C3E53",
#    "profile_use_background_image": true,
#    "has_extended_profile": true,
#    "default_profile": false,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "is_quote_status": false,
#   "retweet_count": 1633,
#   "favorite_count": 4862,
#   "favorited": false,
#   "retweeted": false,
#   "lang": "en"
#  },
#  "is_quote_status": false,
#  "retweet_count": 1633,
#  "favorite_count": 0,
#  "favorited": false,
#  "retweeted": false,
#  "lang": "en"
# }

# %%
# The result of the list comprehension is a list with only one element that
# can be accessed by its index and set to the variable t
t = statuses[0]
#[ status for status in statuses 
#          if status['id'] == 316948241264549888 ][0]

# Explore the variable t to get familiarized with the data structure...
print(t)
print(t.keys())
print(t['text'])
#print(t['retweet_count'])
#print(t['retweeted'])
# Out:
# {'created_at': 'Thu Mar 12 17:32:07 +0000 2020', 'id': 1238155828194152448, 'id_str': '1238155828194152448', 'text': 'RT @Pappiness: When the market drops 7%, it triggers a circuit breaker and stops trading for 15 minutes.\n\nThe first and only time it happen…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'Pappiness', 'name': 'Nick Jack Pappas', 'id': 30726383, 'id_str': '30726383', 'indices': [3, 13]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 17172863, 'id_str': '17172863', 'name': 'Jasper Lucas', 'screen_name': 'JGRIDLOCK', 'location': 'United States', 'description': 'Progressive who loves sports & politics; despise Trumpsters. #SheWonThePopularVote #TrumpIsACriminal #ImpeachTrumpNow #Resistance #FBR', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 3017, 'friends_count': 4987, 'listed_count': 53, 'created_at': 'Tue Nov 04 23:32:01 +0000 2008', 'favourites_count': 99102, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 125945, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1115172205455974400/gjtAZrLw_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1115172205455974400/gjtAZrLw_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Thu Mar 12 13:45:21 +0000 2020', 'id': 1238098758740643841, 'id_str': '1238098758740643841', 'text': 'When the market drops 7%, it triggers a circuit breaker and stops trading for 15 minutes.\n\nThe first and only time… https://t.co/OUbU96p4wH', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/OUbU96p4wH', 'expanded_url': 'https://twitter.com/i/web/status/1238098758740643841', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [116, 139]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 30726383, 'id_str': '30726383', 'name': 'Nick Jack Pappas', 'screen_name': 'Pappiness', 'location': 'New York, NY', 'description': "Writer | Comedian | Director | Filipino-American 🇵🇭🇺🇸. @NBC Late Night Writers' Workshop. @ucbtny writer.", 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 93620, 'friends_count': 3617, 'listed_count': 899, 'created_at': 'Sun Apr 12 21:34:15 +0000 2009', 'favourites_count': 23343, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 5885, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '0C0F0B', 'profile_b ...
# dict_keys(['created_at', 'id', 'id_str', 'text', 'truncated', 'entities', 'metadata', 'source', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'retweeted_status', 'is_quote_status', 'retweet_count', 'favorite_count', 'favorited', 'retweeted', 'lang'])
# RT @Pappiness: When the market drops 7%, it triggers a circuit breaker and stops trading for 15 minutes.
#
# The first and only time it happen…

# %% [markdown]
# ## Example 6. Extracting text, screen names, and hashtags from tweets

# %%
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# %%
# Explore the first 5 items for each...

print(json.dumps(status_texts[0:5], indent=1))
print(json.dumps(screen_names[0:5], indent=1)) 
print(json.dumps(hashtags[0:5], indent=1))
print(json.dumps(words[0:5], indent=1))
# Out:
# [
#  "RT @Pappiness: When the market drops 7%, it triggers a circuit breaker and stops trading for 15 minutes.\n\nThe first and only time it happen\u2026",
#  "RT @raggapegs: '@realdonaldtrump ranked worst president in US history by nearly 200 political scientists.' I'm shocked!\ud83d\ude31 #TrumptheWorstPres\u2026",
#  "RT @AppSame: #TrumptheWorstPresidentEVER\n\nBlaming Trump for the #CoronavirusPandemic \n\nProves how evil @TheDemocrats are",
#  "RT @jackresists: This has been the most bungled response to a crisis I've seen in my lifetime.\n\n#TrumptheWorstPresidentEVER",
#  "Alright, bust out the replacement-bot!\n#TrumptheWorstPresidentEVER \n\n\"President Model #16\"\n[The Spoils - Unlikely H\u2026 https://t.co/qOz9Hko6sj"
# ]
# [
#  "Pappiness",
#  "raggapegs",
#  "realDonaldTrump",
#  "AppSame",
#  "TheDemocrats"
# ]
# [
#  "TrumptheWorstPresidentEVER",
#  "CoronavirusPandemic",
#  "TrumptheWorstPresidentEVER",
#  "TrumptheWorstPresidentEVER",
#  "TrumptheWorstPresidentEVER"
# ]
# [
#  "RT",
#  "@Pappiness:",
#  "When",
#  "the",
#  "market"
# ]

# %% [markdown]
# ## Example 7. Creating a basic frequency distribution from the words in tweets

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print(c.most_common()[:10]) # top 10
    print()
# Out:
# [('RT', 32), ('the', 32), ('#TrumptheWorstPresidentEVER', 26), ('to', 21), ('a', 20), ('and', 19), ('for', 10), ('is', 10), ('Trump', 9), ('of', 9)]
#
# [('realDonaldTrump', 3), ('AynRandPaulRyan', 3), ('raggapegs', 2), ('middleageriot', 2), ('NoNoNotNormal', 2), ('Pappiness', 1), ('AppSame', 1), ('TheDemocrats', 1), ('jackresists', 1), ('415holgate', 1)]
#
# [('TrumptheWorstPresidentEVER', 29), ('CoronavirusPandemic', 8), ('Trumpspeech', 2), ('Covid_19', 2), ('TrumpVirus', 2), ('trumpspeech', 2), ('COVD19', 2), ('TrumpNotFitForOffice', 1), ('hoax', 1), ('CorruptDNC', 1)]

# %% [markdown]
# ## Example 8. Create a prettyprint function to display tuples in a nice tabular format

# %%
def prettyprint_counts(label, list_of_tuples):
    print("\n{:^30} | {:^6}".format(label, "Count"))
    print("*"*60)
    for k,v in list_of_tuples:
        print("{:30} | {:>6}".format(k,v))

# %%
for label, data in (('Word', words), 
                    ('Screen Name', screen_names), 
                    ('Hashtag', hashtags)):
    
    c = Counter(data)
    prettyprint_counts(label, c.most_common()[:10])
# Out:
#              Word              | Count
# ************************************************************
# RT                             |     32
# the                            |     32
# #TrumptheWorstPresidentEVER    |     26
# to                             |     21
# a                              |     20
# and                            |     19
# for                            |     10
# is                             |     10
# Trump                          |      9
# of                             |      9
#
#          Screen Name           | Count
# ************************************************************
# realDonaldTrump                |      3
# AynRandPaulRyan                |      3
# raggapegs                      |      2
# middleageriot                  |      2
# NoNoNotNormal                  |      2
# Pappiness                      |      1
# AppSame                        |      1
# TheDemocrats                   |      1
# jackresists                    |      1
# 415holgate                     |      1
#
#            Hashtag             | Count
# ************************************************************
# TrumptheWorstPresidentEVER     |     29
# CoronavirusPandemic            |      8
# Trumpspeech                    |      2
# Covid_19                       |      2
# TrumpVirus                     |      2
# trumpspeech                    |      2
# COVD19                         |      2
# TrumpNotFitForOffice           |      1
# hoax                           |      1
# CorruptDNC                     |      1

# %% [markdown]
# ## Example 9. Finding the most popular retweets

# %%
retweets = [
            # Store out a tuple of these three values ...
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['text'].replace("\n","\\")) 
            
            # ... for each status ...
            for status in statuses 
            
            # ... so long as the status meets this condition.
                if 'retweeted_status' in status
           ]

# %% [markdown]
# We can build another `prettyprint` function to print entire tweets with their retweet count.
#
# We also want to split the text of the tweet in up to 3 lines, if needed.

# %%
row_template = "{:^7} | {:^15} | {:50}"
def prettyprint_tweets(list_of_tuples):
    print()
    print(row_template.format("Count", "Screen Name", "Text"))
    print("*"*60)
    for count, screen_name, text in list_of_tuples:
        print(row_template.format(count, screen_name, text[:50]))
        if len(text) > 50:
            print(row_template.format("", "", text[50:100]))
            if len(text) > 100:
                print(row_template.format("", "", text[100:]))

# %%
# Slice off the first 5 from the sorted results and display each item in the tuple

prettyprint_tweets(sorted(retweets, reverse=True)[:])
# Out:
#  Count  |   Screen Name   | Text
# ************************************************************
#  2378   | AynRandPaulRyan | RT @AynRandPaulRyan: Savannah Guthrie handing Mike
#         |                 |  Pence his ass on a platter is a whooooooleass moo
#         |                 | d.\\#CoronavirusPandemic #trumpspeech #…
#  1633   |    Pappiness    | RT @Pappiness: When the market drops 7%, it trigge
#         |                 | rs a circuit breaker and stops trading for 15 minu
#         |                 | tes.\\The first and only time it happen…
#  1390   |  middleageriot  | RT @middleageriot: If only there'd been some indic
#         |                 | ation that Donald Trump lacked the intellectual an
#         |                 | d emotional capacity to handle a nation…
#   869   |  middleageriot  | RT @middleageriot: I miss having a president who w
#         |                 | ould be willing to skip a game of golf to keep us
#         |                 | from dying.\\#TrumptheWorstPresidentEVER
